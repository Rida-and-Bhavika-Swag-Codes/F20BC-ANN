# %%
# importing all the libraries required here
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np

# %%
# reading the dataset
datasetNames = ['ID number', 'Diagnosis', 
                'Mean Radius', 'Mean Texture', 'Mean Perimeter', 'Mean Area', 'Mean Smoothness', 'Mean Compactness', 'Mean Concavity', 'Mean Concave Points', 'Mean Symmetry', 'Mean Fractal Dimension',
                'SE Radius', 'SE Texture', 'SE Perimeter', 'SE Area', 'SE Smoothness', 'SE Compactness', 'SE Concavity', 'SE Concave Points', 'SE Symmetry', 'SE Fractal Dimension',
                'Worst Radius', 'Worst Texture', 'Worst Perimeter', 'Worst Area', 'Worst Smoothness', 'Worst Compactness', 'Worst Concavity', 'Worst Concave Points', 'Worst Symmetry', 'Worst Fractal Dimension']
dataset = pd.read_csv('data/wdbc.data', names = datasetNames, sep = ',')
dataset.head()
# Out:
#    ID number Diagnosis  Mean Radius  Mean Texture  Mean Perimeter  Mean Area  \
# 0     842302         M        17.99         10.38          122.80     1001.0
# 1     842517         M        20.57         17.77          132.90     1326.0
# 2   84300903         M        19.69         21.25          130.00     1203.0
# 3   84348301         M        11.42         20.38           77.58      386.1
# 4   84358402         M        20.29         14.34          135.10     1297.0
#
#    Mean Smoothness  Mean Compactness  Mean Concavity  Mean Concave Points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  Worst Radius  Worst Texture  Worst Perimeter  Worst Area  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    Worst Smoothness  Worst Compactness  Worst Concavity  Worst Concave Points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    Worst Symmetry  Worst Fractal Dimension
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
dataset = dataset.drop(columns=['ID number'])
m , n = dataset.shape  # m = no. of samples, n = no. of features + target class
dataset = dataset.T #each column now represents a training set
dataset.head()
# Out:
#                    0       1       2      3       4      5       6      7    \
# Diagnosis            M       M       M      M       M      M       M      M
# Mean Radius      17.99   20.57   19.69  11.42   20.29  12.45   18.25  13.71
# Mean Texture     10.38   17.77   21.25  20.38   14.34   15.7   19.98  20.83
# Mean Perimeter   122.8   132.9   130.0  77.58   135.1  82.57   119.6   90.2
# Mean Area       1001.0  1326.0  1203.0  386.1  1297.0  477.1  1040.0  577.9
#
#                   8      9    ...    559    560    561    562     563     564  \
# Diagnosis           M      M  ...      B      B      B      M       M       M
# Mean Radius      13.0  12.46  ...  11.51  14.05   11.2  15.22   20.92   21.56
# Mean Texture    21.82  24.04  ...  23.93  27.15  29.37  30.62   25.09   22.39
# Mean Perimeter   87.5  83.97  ...  74.52  91.38  70.67  103.4   143.0   142.0
# Mean Area       519.8  475.9  ...  403.5  600.4  386.0  716.9  1347.0  1479.0
#
#                    565    566     567    568
# Diagnosis            M      M       M      B
# Mean Radius      20.13   16.6    20.6   7.76
# Mean Texture     28.25  28.08   29.33  24.54
# Mean Perimeter   131.2  108.3   140.1  47.92
# Mean Area       1261.0  858.1  1265.0  181.0
#
# [5 rows x 569 columns]

# %%
# seperate target class from dataset

Y_train = dataset.iloc[0]
X_train = dataset.iloc[1:n]

print(Y_train)
print(X_train)
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: Diagnosis, Length: 569, dtype: object
#                               0         1         2         3         4    \
# Mean Radius                 17.99     20.57     19.69     11.42     20.29
# Mean Texture                10.38     17.77     21.25     20.38     14.34
# Mean Perimeter              122.8     132.9     130.0     77.58     135.1
# Mean Area                  1001.0    1326.0    1203.0     386.1    1297.0
# Mean Smoothness            0.1184   0.08474    0.1096    0.1425    0.1003
# Mean Compactness           0.2776   0.07864    0.1599    0.2839    0.1328
# Mean Concavity             0.3001    0.0869    0.1974    0.2414     0.198
# Mean Concave Points        0.1471   0.07017    0.1279    0.1052    0.1043
# Mean Symmetry              0.2419    0.1812    0.2069    0.2597    0.1809
# Mean Fractal Dimension    0.07871   0.05667   0.05999   0.09744   0.05883
# SE Radius                   1.095    0.5435    0.7456    0.4956    0.7572
# SE Texture                 0.9053    0.7339    0.7869     1.156    0.7813
# SE Perimeter                8.589     3.398     4.585     3.445     5.438
# SE Area                     153.4     74.08     94.03     27.23     94.44
# SE Smoothness            0.006399  0.005225   0.00615   0.00911   0.01149
# SE Compactness            0.04904   0.01308   0.04006   0.07458   0.02461
# SE Concavity              0.05373    0.0186   0.03832   0.05661   0.05688
# SE Concave Points         0.01587    0.0134   0.02058   0.01867   0.01885
# SE Symmetry               0.03003   0.01389    0.0225   0.05963   0.01756
# SE Fractal Dimension     0.006193  0.003532  0.004571  0.009208  0.005115
# Worst Radius                25.38     24.99     23.57     14.91     22.54
# Worst Texture               17.33     23.41     25.53      26.5     16.67
# Worst Perimeter             184.6     158.8     152.5     98.87     152.2
# Worst Area                 2019.0    1956.0    1709.0     567.7    1575.0
# Worst Smoothness           0.1622    0.1238    0.1444    0.2098    0.1374
# Worst Compactness          0.6656    0.1866    0.4245    0.8663     0.205
# Worst Concavity            0.7119    0.2416    0.4504    0.6869       0.4
# Worst Concave Points       0.2654     0.186     0.243    0.2575    0.1625
# Worst Symmetry             0.4601     0.275    0.3613    0.6638    0.2364
# Worst Fractal Dimension    0.1189   0.08902   0.08758     0.173   0.07678
#
#                               5         6         7         8         9    \
# Mean Radius                 12.45     18.25     13.71      13.0     12.46
# Mean Texture                 15.7     19.98     20.83     21.82     24.04
# Mean Perimeter              82.57     119.6      90.2      87.5     83.97
# Mean Area                   477.1    1040.0     577.9     519.8     475.9
# Mean Smoothness            0.1278   0.09463    0.1189    0.1273    0.1186
# Mean Compactness             0.17     0.109    0.1645    0.1932    0.2396
# Mean Concavity             0.1578    0.1127   0.09366    0.1859    0.2273
# Mean Concave Points       0.08089     0.074   0.05985   0.09353   0.08543
# Mean Symmetry              0.2087    0.1794    0.2196     0.235     0.203
# Mean Fractal Dimension    0.07613   0.05742   0.07451   0.07389   0.08243
# SE Radius                  0.3345    0.4467    0.5835    0.3063    0.2976
# SE Texture                 0.8902    0.7732     1.377     1.002     1.599
# SE Perimeter                2.217      3.18     3.856     2.406     2.039
# SE Area                     27.19     53.91     50.96     24.32     23.94
# SE Smoothness             0.00751  0.004314  0.008805  0.005731  0.007149
# SE Compactness            0.03345   0.01382   0.03029   0.03502   0.07217
# SE Concavity              0.03672   0.02254   0.02488   0.03553   0.07743
# SE Concave Points         0.01137   0.01039   0.01448   0.01226   0.01432
# SE Symmetry               0.02165   0.01369   0.01486   0.02143   0.01789
# SE Fractal Dimension     0.005082  0.002179  0.005412  0.003749   0.01008
# Worst Radius                15.47     22.88     17.06     15.49     15.09
# Worst Texture               23.75     27.66     28.14     30.73     40.68
# Worst Perimeter             103.4     153.2     110.6     106.2     97.65
# Worst Area                  741.6    1606.0     897.0     739.3     711.4
# Worst Smoothness           0.1791    0.1442    0.1654    0.1703    0.1853
# Worst Compactness          0.5249    0.2576    0.3682    0.5401     1.058
# Worst Concavity            0.5355    0.3784    0.2678     0.539     1.105
# Worst Concave Points       0.1741    0.1932    0.1556     0.206     0.221
# Worst Symmetry             0.3985    0.3063    0.3196    0.4378    0.4366
# Worst Fractal Dimension    0.1244   0.08368    0.1151    0.1072    0.2075
#
#                          ...       559       560       561       562  \
# Mean Radius              ...     11.51     14.05      11.2     15.22
# Mean Texture             ...     23.93     27.15     29.37     30.62
# Mean Perimeter           ...     74.52     91.38     70.67     103.4
# Mean Area                ...     403.5     600.4     386.0     716.9
# Mean Smoothness          ...   0.09261   0.09929   0.07449    0.1048
# Mean Compactness         ...    0.1021    0.1126   0.03558    0.2087
# Mean Concavity           ...    0.1112   0.04462       0.0     0.255
# Mean Concave Points      ...   0.04105   0.04304       0.0   0.09429
# Mean Symmetry            ...    0.1388    0.1537     0.106    0.2128
# Mean Fractal Dimension   ...    0.0657   0.06171   0.05502   0.07152
# SE Radius                ...    0.2388    0.3645    0.3141    0.2602
# SE Texture               ...     2.904     1.492     3.896     1.205
# SE Perimeter             ...     1.936     2.888     2.041     2.362
# SE Area                  ...     16.97     29.84     22.81     22.65
# SE Smoothness            ...    0.0082  0.007256  0.007594  0.004625
# SE Compactness           ...   0.02982   0.02678  0.008878   0.04844
# SE Concavity             ...   0.05738   0.02071       0.0   0.07359
# SE Concave Points        ...   0.01267   0.01626       0.0   0.01608
# SE Symmetry              ...   0.01488    0.0208   0.01989   0.02137
# SE Fractal Dimension     ...  0.004738  0.005304  0.001773  0.006142
# Worst Radius             ...     12.48      15.3     11.92     17.52
# Worst Texture            ...     37.16     33.17      38.3     42.79
# Worst Perimeter          ...     82.28     100.2     75.19     128.7
# Worst Area               ...     474.2     706.7     439.6     915.0
# Worst Smoothness         ...    0.1298    0.1241   0.09267    0.1417
# Worst Compactness        ...    0.2517    0.2264   0.05494    0.7917
# Worst Concavity          ...     0.363    0.1326       0.0      1.17
# Worst Concave Points     ...   0.09653    0.1048       0.0    0.2356
# Worst Symmetry           ...    0.2112     0.225    0.1566    0.4089
# Worst Fractal Dimension  ...   0.08732   0.08321   0.05905    0.1409
#
#                               563       564       565       566       567  \
# Mean Radius                 20.92     21.56     20.13      16.6      20.6
# Mean Texture                25.09     22.39     28.25     28.08     29.33
# Mean Perimeter              143.0     142.0     131.2     108.3     140.1
# Mean Area                  1347.0    1479.0    1261.0     858.1    1265.0
# Mean Smoothness            0.1099     0.111    0.0978   0.08455    0.1178
# Mean Compactness           0.2236    0.1159    0.1034    0.1023     0.277
# Mean Concavity             0.3174    0.2439     0.144   0.09251    0.3514
# Mean Concave Points        0.1474    0.1389   0.09791   0.05302     0.152
# Mean Symmetry              0.2149    0.1726    0.1752     0.159    0.2397
# Mean Fractal Dimension    0.06879   0.05623   0.05533   0.05648   0.07016
# SE Radius                  0.9622     1.176    0.7655    0.4564     0.726
# SE Texture                  1.026     1.256     2.463     1.075     1.595
# SE Perimeter                8.758     7.673     5.203     3.425     5.772
# SE Area                     118.8     158.7     99.04     48.55     86.22
# SE Smoothness            0.006399    0.0103  0.005769  0.005903  0.006522
# SE Compactness             0.0431   0.02891   0.02423   0.03731   0.06158
# SE Concavity              0.07845   0.05198    0.0395    0.0473   0.07117
# SE Concave Points         0.02624   0.02454   0.01678   0.01557   0.01664
# SE Symmetry               0.02057   0.01114   0.01898   0.01318   0.02324
# SE Fractal Dimension     0.006213  0.004239  0.002498  0.003892  0.006185
# Worst Radius                24.29     25.45     23.69     18.98     25.74
# Worst Texture               29.41      26.4     38.25     34.12     39.42
# Worst Perimeter             179.1     166.1     155.0     126.7     184.6
# Worst Area                 1819.0    2027.0    1731.0    1124.0    1821.0
# Worst Smoothness           0.1407     0.141    0.1166    0.1139     0.165
# Worst Compactness          0.4186    0.2113    0.1922    0.3094    0.8681
# Worst Concavity            0.6599    0.4107    0.3215    0.3403    0.9387
# Worst Concave Points       0.2542    0.2216    0.1628    0.1418     0.265
# Worst Symmetry             0.2929     0.206    0.2572    0.2218    0.4087
# Worst Fractal Dimension   0.09873   0.07115   0.06637    0.0782     0.124
#
#                               568
# Mean Radius                  7.76
# Mean Texture                24.54
# Mean Perimeter              47.92
# Mean Area                   181.0
# Mean Smoothness           0.05263
# Mean Compactness          0.04362
# Mean Concavity                0.0
# Mean Concave Points           0.0
# Mean Symmetry              0.1587
# Mean Fractal Dimension    0.05884
# SE Radius                  0.3857
# SE Texture                  1.428
# SE Perimeter                2.548
# SE Area                     19.15
# SE Smoothness            0.007189
# SE Compactness            0.00466
# SE Concavity                  0.0
# SE Concave Points             0.0
# SE Symmetry               0.02676
# SE Fractal Dimension     0.002783
# Worst Radius                9.456
# Worst Texture               30.37
# Worst Perimeter             59.16
# Worst Area                  268.6
# Worst Smoothness          0.08996
# Worst Compactness         0.06444
# Worst Concavity               0.0
# Worst Concave Points          0.0
# Worst Symmetry             0.2871
# Worst Fractal Dimension   0.07039
#
# [30 rows x 569 columns]

# %%
# Initialise ANN
import ANN
import layer
"""REMOVE BEFORE SUBMISSION"""
import importlib
importlib.reload(ANN)
importlib.reload(layer)

# categorizing data into numericals, 0 = M, 1 = B
Y_train = pd.factorize(Y_train)[0]

# testing one hot encoder
Y_train = ANN.one_hot_encode(Y_train, 2)

# initialise with learning rate, choice of loss funciton, input vector, output vector
ann = ANN.ANN(0.1,1,X_train,Y_train)
activations = [1,2,3,3] # 0-tanh, 1-relu, 2-sigmoid - activations of each non-output layer
ann.setLayers(activations, 7, 5, 3, 2) # variable arguments represent the number of nodes in each non-input layer 
i = 0
for l in ann.layers:
    print("\nProperties of layer", i, ":")
    l.get_properties()
    i += 1

print("Training Network")
ann.train()

i = 0
for l in ann.layers:
    print("\nProperties of layer", i, ":")
    l.get_properties()
    i += 1
# Out:
# the activations are [1, 2, 3, 3]
# the variable argument is  (7, 5, 3, 2)
# number of hidden layers 3
#
# adding input layer
# added 1 hidden layer
# added 1 hidden layer
# added 1 hidden layer
# added 1 output layer
#
# Properties of layer 0 :
# Number of nodes: 30
# Activation Function: <function tanh at 0x000002238929C4C0>
# Weights: [[-0.4997119   0.13297297 -0.41591417  0.35917229 -0.45778334 -0.08439091
#   -0.41871004 -0.06705111  0.32436139 -0.18832124  0.33818021 -0.12040355
#    0.24077787  0.40736011 -0.20718355  0.48900903  0.12762813  0.09170152
#    0.01976313 -0.42005795  0.18006646 -0.19447133 -0.45957021  0.16668093
#    0.20097097  0.10737283 -0.26125271 -0.04341286  0.05626388 -0.21865617]
#  [-0.42650051  0.4508847   0.02031291 -0.18770645  0.1031049   0.00510609
#   -0.41268986  0.16649674 -0.21231733 -0.29006302  0.42635777  0.42727332
#    0.33979419 -0.0637388  -0.44927625  0.17713738 -0.19266237  0.44634861
#    0.23872767  0.22290211  0.10971364 -0.01917512  0.44928957  0.04192593
#    0.33240353  0.30358262 -0.03875865 -0.0480901  -0.2984334  -0.30563844]
#  [-0.03218781  0.09961584  0.02037542 -0.24948072  0.47082385 -0.29169891
#    0.32375377 -0.34172758  0.00849481 -0.05018044 -0.20807897 -0.38515022
#   -0.14566859  0.12878809 -0.12805768 -0.27071693  0.14701615 -0.46138442
#   -0.44175015  0.34091005  0.10270928  0.0356802   0.1783325  -0.21410825
#   -0.3485062  -0.44293287  0.21850526  0.34885369 -0.02498802 -0.00134541]
#  [ 0.26238793 -0.16825446 -0.32566276 -0.29452346 -0.1090824  -0.33122815
#    0.02190242 -0.4563339  -0.43383561  0.1560404  -0.14404451 -0.32235934
#    0.32933327 -0.49265006  0.20243137  0.23471572 -0.49072898 -0.19352359
#    0.41321947  0.30948878 -0.09368896 -0.43483307 -0.29623527  0.38717428
#   -0.01497723  0.4610528  -0.32100511 -0.1534708   0.46887019  0.18901961]
#  [-0.21503701 -0.27875751 -0.08772422 -0.01029944 -0.38780839 -0.22609365
#   -0.16151567  0.05733576 -0.25316402 -0.04428126  0.01153687  0.27482972
#   -0.11441054 -0.14296995  0.44798052 -0.26146578 -0.45237848  0.44343713
#   -0.0552406   0.01502584 -0.20524592  0.27757359  0.18882722 -0.10686173
#   -0.09151189  0.48600888 -0.02642699 -0.34707148 -0.25811556 -0.31945486]
#  [ 0.10398785 -0.48738963  0.42416618  0.09348691  0.409861    0.35822887
#    0.26699864  0.29602225  0.13445532 -0.26377369  0.22079716 -0.22169748
#    0.33469685  0.25201568 -0.49657707  0.19285012 -0.36055394  0.42934802
#   -0.23131911 -0.09908511  0.25357962 -0.38984331  0.10546747 -0.15552199
#    0.42193227 -0.23978183  0.34443628 -0.38201212  0.07384323  0.4910545 ]
#  [-0.24903101  0.17491862  0.11726665 -0.23459026 -0.14338896  0.00136828
#   -0.32915799  0.11924851  0.06414837 -0.38861208  0.33666136 -0.03836721
#   -0.26579629  0.42370599  0.26916204 -0.25859051  0.3705949  -0.31933546
#   -0.24607841  0.08458885 -0.41773521  0.252347    0.14844841 -0.30939962
#   -0.18313911 -0.05811418  0.15658811  0.45048571 -0.18683211 -0.13043165]]
# Bias: [[-0.48210797]
#  [-0.13009044]
#  [-0.17004687]
#  [ 0.2064478 ]
#  [-0.41419128]
#  [-0.19070545]
#  [ 0.12653221]]
# Input vector:                               0         1         2         3         4    \
# Mean Radius                 17.99     20.57     19.69     11.42     20.29
# Mean Texture                10.38     17.77     21.25     20.38     14.34
# Mean Perimeter              122.8     132.9     130.0     77.58     135.1
# Mean Area                  1001.0    1326.0    1203.0     386.1    1297.0
# Mean Smoothness            0.1184   0.08474    0.1096    0.1425    0.1003
# Mean Compactness           0.2776   0.07864    0.1599    0.2839    0.1328
# Mean Concavity             0.3001    0.0869    0.1974    0.2414     0.198
# Mean Concave Points        0.1471   0.07017    0.1279    0.1052    0.1043
# Mean Symmetry              0.2419    0.1812    0.2069    0.2597    0.1809
# Mean Fractal Dimension    0.07871   0.05667   0.05999   0.09744   0.05883
# SE Radius                   1.095    0.5435    0.7456    0.4956    0.7572
# SE Texture                 0.9053    0.7339    0.7869     1.156    0.7813
# SE Perimeter                8.589     3.398     4.585     3.445     5.438
# SE Area                     153.4     74.08     94.03     27.23     94.44
# SE Smoothness            0.006399  0.005225   0.00615   0.00911   0.01149
# SE Compactness            0.04904   0.01308   0.04006   0.07458   0.02461
# SE Concavity              0.05373    0.0186   0.03832   0.05661   0.05688
# SE Concave Points         0.01587    0.0134   0.02058   0.01867   0.01885
# SE Symmetry               0.03003   0.01389    0.0225   0.05963   0.01756
# SE Fractal Dimension     0.006193  0.003532  0.004571  0.009208  0.005115
# Worst Radius                25.38     24.99     23.57     14.91     22.54
# Worst Texture               17.33     23.41     25.53      26.5     16.67
# Worst Perimeter             184.6     158.8     152.5     98.87     152.2
# Worst Area                 2019.0    1956.0    1709.0     567.7    1575.0
# Worst Smoothness           0.1622    0.1238    0.1444    0.2098    0.1374
# Worst Compactness          0.6656    0.1866    0.4245    0.8663     0.205
# Worst Concavity            0.7119    0.2416    0.4504    0.6869       0.4
# Worst Concave Points       0.2654     0.186     0.243    0.2575    0.1625
# Worst Symmetry             0.4601     0.275    0.3613    0.6638    0.2364
# Worst Fractal Dimension    0.1189   0.08902   0.08758     0.173   0.07678
#
#                               5         6         7         8         9    \
# Mean Radius                 12.45     18.25     13.71      13.0     12.46
# Mean Texture                 15.7     19.98     20.83     21.82     24.04
# Mean Perimeter              82.57     119.6      90.2      87.5     83.97
# Mean Area                   477.1    1040.0     577.9     519.8     475.9
# Mean Smoothness            0.1278   0.09463    0.1189    0.1273    0.1186
# Mean Compactness             0.17     0.109    0.1645    0.1932    0.2396
# Mean Concavity             0.1578    0.1127   0.09366    0.1859    0.2273
# Mean Concave Points       0.08089     0.074   0.05985   0.09353   0.08543
# Mean Symmetry              0.2087    0.1794    0.2196     0.235     0.203
# Mean Fractal Dimension    0.07613   0.05742   0.07451   0.07389   0.08243
# SE Radius                  0.3345    0.4467    0.5835    0.3063    0.2976
# SE Texture                 0.8902    0.7732     1.377     1.002     1.599
# SE Perimeter                2.217      3.18     3.856     2.406     2.039
# SE Area                     27.19     53.91     50.96     24.32     23.94
# SE Smoothness             0.00751  0.004314  0.008805  0.005731  0.007149
# SE Compactness            0.03345   0.01382   0.03029   0.03502   0.07217
# SE Concavity              0.03672   0.02254   0.02488   0.03553   0.07743
# SE Concave Points         0.01137   0.01039   0.01448   0.01226   0.01432
# SE Symmetry               0.02165   0.01369   0.01486   0.02143   0.01789
# SE Fractal Dimension     0.005082  0.002179  0.005412  0.003749   0.01008
# Worst Radius                15.47     22.88     17.06     15.49     15.09
# Worst Texture               23.75     27.66     28.14     30.73     40.68
# Worst Perimeter             103.4     153.2     110.6     106.2     97.65
# Worst Area                  741.6    1606.0     897.0     739.3     711.4
# Worst Smoothness           0.1791    0.1442    0.1654    0.1703    0.1853
# Worst Compactness          0.5249    0.2576    0.3682    0.5401     1.058
# Worst Concavity            0.5355    0.3784    0.2678     0.539     1.105
# Worst Concave Points       0.1741    0.1932    0.1556     0.206     0.221
# Worst Symmetry             0.3985    0.3063    0.3196    0.4378    0.4366
# Worst Fractal Dimension    0.1244   0.08368    0.1151    0.1072    0.2075
#
#                          ...       559       560       561       562  \
# Mean Radius              ...     11.51     14.05      11.2     15.22
# Mean Texture             ...     23.93     27.15     29.37     30.62
# Mean Perimeter           ...     74.52     91.38     70.67     103.4
# Mean Area                ...     403.5     600.4     386.0     716.9
# Mean Smoothness          ...   0.09261   0.09929   0.07449    0.1048
# Mean Compactness         ...    0.1021    0.1126   0.03558    0.2087
# Mean Concavity           ...    0.1112   0.04462       0.0     0.255
# Mean Concave Points      ...   0.04105   0.04304       0.0   0.09429
# Mean Symmetry            ...    0.1388    0.1537     0.106    0.2128
# Mean Fractal Dimension   ...    0.0657   0.06171   0.05502   0.07152
# SE Radius                ...    0.2388    0.3645    0.3141    0.2602
# SE Texture               ...     2.904     1.492     3.896     1.205
# SE Perimeter             ...     1.936     2.888     2.041     2.362
# SE Area                  ...     16.97     29.84     22.81     22.65
# SE Smoothness            ...    0.0082  0.007256  0.007594  0.004625
# SE Compactness           ...   0.02982   0.02678  0.008878   0.04844
# SE Concavity             ...   0.05738   0.02071       0.0   0.07359
# SE Concave Points        ...   0.01267   0.01626       0.0   0.01608
# SE Symmetry              ...   0.01488    0.0208   0.01989   0.02137
# SE Fractal Dimension     ...  0.004738  0.005304  0.001773  0.006142
# Worst Radius             ...     12.48      15.3     11.92     17.52
# Worst Texture            ...     37.16     33.17      38.3     42.79
# Worst Perimeter          ...     82.28     100.2     75.19     128.7
# Worst Area               ...     474.2     706.7     439.6     915.0
# Worst Smoothness         ...    0.1298    0.1241   0.09267    0.1417
# Worst Compactness        ...    0.2517    0.2264   0.05494    0.7917
# Worst Concavity          ...     0.363    0.1326       0.0      1.17
# Worst Concave Points     ...   0.09653    0.1048       0.0    0.2356
# Worst Symmetry           ...    0.2112     0.225    0.1566    0.4089
# Worst Fractal Dimension  ...   0.08732   0.08321   0.05905    0.1409
#
#                               563       564       565       566       567  \
# Mean Radius                 20.92     21.56     20.13      16.6      20.6
# Mean Texture                25.09     22.39     28.25     28.08     29.33
# Mean Perimeter              143.0     142.0     131.2     108.3     140.1
# Mean Area                  1347.0    1479.0    1261.0     858.1    1265.0
# Mean Smoothness            0.1099     0.111    0.0978   0.08455    0.1178
# Mean Compactness           0.2236    0.1159    0.1034    0.1023     0.277
# Mean Concavity             0.3174    0.2439     0.144   0.09251    0.3514
# Mean Concave Points        0.1474    0.1389   0.09791   0.05302     0.152
# Mean Symmetry              0.2149    0.1726    0.1752     0.159    0.2397
# Mean Fractal Dimension    0.06879   0.05623   0.05533   0.05648   0.07016
# SE Radius                  0.9622     1.176    0.7655    0.4564     0.726
# SE Texture                  1.026     1.256     2.463     1.075     1.595
# SE Perimeter                8.758     7.673     5.203     3.425     5.772
# SE Area                     118.8     158.7     99.04     48.55     86.22
# SE Smoothness            0.006399    0.0103  0.005769  0.005903  0.006522
# SE Compactness             0.0431   0.02891   0.02423   0.03731   0.06158
# SE Concavity              0.07845   0.05198    0.0395    0.0473   0.07117
# SE Concave Points         0.02624   0.02454   0.01678   0.01557   0.01664
# SE Symmetry               0.02057   0.01114   0.01898   0.01318   0.02324
# SE Fractal Dimension     0.006213  0.004239  0.002498  0.003892  0.006185
# Worst Radius                24.29     25.45     23.69     18.98     25.74
# Worst Texture               29.41      26.4     38.25     34.12     39.42
# Worst Perimeter             179.1     166.1     155.0     126.7     184.6
# Worst Area                 1819.0    2027.0    1731.0    1124.0    1821.0
# Worst Smoothness           0.1407     0.141    0.1166    0.1139     0.165
# Worst Compactness          0.4186    0.2113    0.1922    0.3094    0.8681
# Worst Concavity            0.6599    0.4107    0.3215    0.3403    0.9387
# Worst Concave Points       0.2542    0.2216    0.1628    0.1418     0.265
# Worst Symmetry             0.2929     0.206    0.2572    0.2218    0.4087
# Worst Fractal Dimension   0.09873   0.07115   0.06637    0.0782     0.124
#
#                               568
# Mean Radius                  7.76
# Mean Texture                24.54
# Mean Perimeter              47.92
# Mean Area                   181.0
# Mean Smoothness           0.05263
# Mean Compactness          0.04362
# Mean Concavity                0.0
# Mean Concave Points           0.0
# Mean Symmetry              0.1587
# Mean Fractal Dimension    0.05884
# SE Radius                  0.3857
# SE Texture                  1.428
# SE Perimeter                2.548
# SE Area                     19.15
# SE Smoothness            0.007189
# SE Compactness            0.00466
# SE Concavity                  0.0
# SE Concave Points             0.0
# SE Symmetry               0.02676
# SE Fractal Dimension     0.002783
# Worst Radius                9.456
# Worst Texture               30.37
# Worst Perimeter             59.16
# Worst Area                  268.6
# Worst Smoothness          0.08996
# Worst Compactness         0.06444
# Worst Concavity               0.0
# Worst Concave Points          0.0
# Worst Symmetry             0.2871
# Worst Fractal Dimension   0.07039
#
# [30 rows x 569 columns]
# Output vector: None
#
# Properties of layer 1 :
# Number of nodes: 7
# Activation Function: <function relu at 0x0000022388B357E0>
# Weights: [[-0.24884456 -0.09365403 -0.34050631  0.44924307 -0.37758986  0.30570046
#   -0.03043247]
#  [-0.49367962 -0.00552631 -0.21084322 -0.01216426  0.41693752  0.37280181
#    0.4283018 ]
#  [ 0.26084947  0.34392855 -0.30513981 -0.38501676 -0.4924709  -0.11106087
#    0.03035728]
#  [ 0.13166841  0.16944626 -0.22169575  0.02310092  0.11401521  0.46783351
#    0.13854912]
#  [-0.19060017  0.34686684  0.31153725  0.1997509  -0.25329324  0.3603149
#   -0.14939767]]
# Bias: [[ 0.1668413 ]
#  [ 0.05678816]
#  [ 0.26141022]
#  [ 0.16552412]
#  [-0.33943326]]
# Input vector: None
# Output vector: None
#
# Properties of layer 2 :
# Number of nodes: 5
# Activation Function: <function sigmoid at 0x00000223893EBA30>
# Weights: [[ 0.45942492 -0.45090876  0.15247504 -0.45088507  0.0660619 ]
#  [ 0.14426702 -0.35364665 -0.48756477  0.02259967  0.49349688]
#  [-0.48688903 -0.21427302  0.0622836  -0.11795746 -0.24147941]]
# Bias: [[-0.09763807]
#  [ 0.3757529 ]
#  [ 0.48850715]]
# Input vector: None
# Output vector: None
#
# Properties of layer 3 :
# Number of nodes: 3
# Activation Function: <function sigmoid at 0x00000223893EBA30>
# Weights: [[-0.02514662 -0.37256448  0.21679773]
#  [ 0.25384051 -0.10619631 -0.17707518]]
# Bias: [[-0.38321587]
#  [ 0.49329154]]
# Input vector: None
# Output vector: None
#
# Properties of layer 4 :
# Number of nodes: 2
# Activation Function: None
# Weights: []
# Bias: []
# Input vector: None
# Output vector: None
# Training Network
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# ...
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
#
# mean loss: 4.467640525238388
# propogating forward
# propogating forward
# propogating forward
# propogating forward
# in gd
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [67], line 26
#      23     i += 1
#      25 print("Training Network")
# ---> 26 ann.train()
#      28 i = 0
#      29 for l in ann.layers:
#
# File c:\Users\ridap\desktop\yr4\f20bc\cw1\F20BC-ANN\ANN.py:43, in ANN.train(self)
#      41 self.layers[-1].input = self.layers[-2].output #set activations of the last layer
#      42 # gradient descent
# ---> 43 print("\nmean loss:", self.sgd(self.input, self.output, 2))
#
# File c:\Users\ridap\desktop\yr4\f20bc\cw1\F20BC-ANN\ANN.py:97, in ANN.sgd(self, X, Y, nclasses)
#      95 pred = self.layers[-1].input.T
#      96 for p, y in zip(pred, Y):
# ---> 97     total_loss += self.loss_function(p, y)
#      98     error = self.loss_prime(p, y)
#     100     for i in range(len(self.layers)-1, -1):
#
# File c:\Users\ridap\desktop\yr4\f20bc\cw1\F20BC-ANN\ANN.py:121, in mse(pred, y)
#     120 def mse(pred, y):
# --> 121     return np.mean(np.power(y - pred, 2))
#
# KeyboardInterrupt:
