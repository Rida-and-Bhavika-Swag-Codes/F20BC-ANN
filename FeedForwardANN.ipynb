# %%
# importing all the libraries required here
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np

# %%
# reading the dataset
datasetNames = ['ID number', 'Diagnosis', 
                'Mean Radius', 'Mean Texture', 'Mean Perimeter', 'Mean Area', 'Mean Smoothness', 'Mean Compactness', 'Mean Concavity', 'Mean Concave Points', 'Mean Symmetry', 'Mean Fractal Dimension',
                'SE Radius', 'SE Texture', 'SE Perimeter', 'SE Area', 'SE Smoothness', 'SE Compactness', 'SE Concavity', 'SE Concave Points', 'SE Symmetry', 'SE Fractal Dimension',
                'Worst Radius', 'Worst Texture', 'Worst Perimeter', 'Worst Area', 'Worst Smoothness', 'Worst Compactness', 'Worst Concavity', 'Worst Concave Points', 'Worst Symmetry', 'Worst Fractal Dimension']
dataset = pd.read_csv('data/wdbc.data', names = datasetNames, sep = ',')
dataset.head()
# Out:
#    ID number Diagnosis  Mean Radius  Mean Texture  Mean Perimeter  Mean Area  \
# 0     842302         M        17.99         10.38          122.80     1001.0
# 1     842517         M        20.57         17.77          132.90     1326.0
# 2   84300903         M        19.69         21.25          130.00     1203.0
# 3   84348301         M        11.42         20.38           77.58      386.1
# 4   84358402         M        20.29         14.34          135.10     1297.0
#
#    Mean Smoothness  Mean Compactness  Mean Concavity  Mean Concave Points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  Worst Radius  Worst Texture  Worst Perimeter  Worst Area  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    Worst Smoothness  Worst Compactness  Worst Concavity  Worst Concave Points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    Worst Symmetry  Worst Fractal Dimension
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
dataset = dataset.drop(columns=['ID number'])
m , n = dataset.shape  # m = no. of samples, n = no. of features + target class
dataset = dataset.T #each column now represents a training set
dataset.head()
# Out:
#                    0       1       2      3       4      5       6      7    \
# Diagnosis            M       M       M      M       M      M       M      M
# Mean Radius      17.99   20.57   19.69  11.42   20.29  12.45   18.25  13.71
# Mean Texture     10.38   17.77   21.25  20.38   14.34   15.7   19.98  20.83
# Mean Perimeter   122.8   132.9   130.0  77.58   135.1  82.57   119.6   90.2
# Mean Area       1001.0  1326.0  1203.0  386.1  1297.0  477.1  1040.0  577.9
#
#                   8      9    ...    559    560    561    562     563     564  \
# Diagnosis           M      M  ...      B      B      B      M       M       M
# Mean Radius      13.0  12.46  ...  11.51  14.05   11.2  15.22   20.92   21.56
# Mean Texture    21.82  24.04  ...  23.93  27.15  29.37  30.62   25.09   22.39
# Mean Perimeter   87.5  83.97  ...  74.52  91.38  70.67  103.4   143.0   142.0
# Mean Area       519.8  475.9  ...  403.5  600.4  386.0  716.9  1347.0  1479.0
#
#                    565    566     567    568
# Diagnosis            M      M       M      B
# Mean Radius      20.13   16.6    20.6   7.76
# Mean Texture     28.25  28.08   29.33  24.54
# Mean Perimeter   131.2  108.3   140.1  47.92
# Mean Area       1261.0  858.1  1265.0  181.0
#
# [5 rows x 569 columns]

# %%
# seperate target class from dataset

Y_train = dataset.iloc[0]
X_train = dataset.iloc[1:n].values.reshape(1, 30*569)
X_train = X_train.astype('float32')
X_train /= 255
print(Y_train)
print(X_train.shape)
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: Diagnosis, Length: 569, dtype: object
# (1, 17070)

# %%
# Initialise ANN
import ANN
import layer
"""REMOVE BEFORE SUBMISSION"""
import importlib
importlib.reload(ANN)
importlib.reload(layer)

# categorizing data into numericals, 0 = M, 1 = B
Y_train = pd.factorize(Y_train)[0]

# testing one hot encoder
Y_train = ANN.one_hot_encode(Y_train, 2)

# initialise with learning rate, choice of loss funciton, input vector, output vector
ann = ANN.ANN(0.1,1,X_train,Y_train)
activations = [1,2,3,3] # 0-tanh, 1-relu, 2-sigmoid - activations of each non-output layer
ann.setLayers(activations, 7, 5, 3, 2) # variable arguments represent the number of nodes in each non-input layer 
i = 0
for l in ann.layers:
    print("\nProperties of layer", i, ":")
    l.get_properties()
    i += 1

print("Training Network")
ann.train()

i = 0
for l in ann.layers:
    print("\nProperties of layer", i, ":")
    l.get_properties()
    i += 1
# Out:
# the activations are [1, 2, 3, 3]
# the variable argument is  (7, 5, 3, 2)
# number of hidden layers 3
#
# adding input layer
# added 1 hidden layer
# added 1 hidden layer
# added 1 hidden layer
# added 1 output layer
#
# Properties of layer 0 :
# Number of nodes: 17070
# Activation Function: <function tanh at 0x000001AE81198040>
# Weights: [[-0.43390314 -0.25724819 -0.25014065 ... -0.03303438 -0.19470145
#    0.00586885]
#  [ 0.05876092  0.49629002 -0.36313156 ...  0.40261461 -0.18852823
#    0.25043922]
#  [-0.49713232  0.08030451 -0.08379758 ...  0.28261083  0.13586633
#   -0.01630298]
#  ...
#  [ 0.48835643 -0.44622615  0.0447683  ...  0.43854018 -0.02988823
#   -0.32782071]
#  [-0.2521786   0.26708724 -0.03271234 ...  0.0311363   0.168245
#   -0.45746944]
#  [ 0.32424323  0.14747223  0.07042914 ... -0.23783297 -0.0417832
#   -0.4111563 ]]
# Bias: [[-0.43753005]
#  [-0.2128031 ]
#  [-0.37072327]
#  [ 0.48155075]
#  [ 0.35348997]
#  [ 0.44927296]
#  [ 0.35312361]]
# Input vector: [[0.07054902 0.08066667 0.07721569 ... 0.00030667 0.00048627 0.00027604]]
# Output vector: None
#
# Properties of layer 1 :
# Number of nodes: 7
# Activation Function: <function relu at 0x000001AE861CB130>
# Weights: [[ 0.41065762  0.28599741 -0.17413884 -0.48388106 -0.23405945 -0.43801468
#    0.42638306]
#  [-0.02167993  0.30638922  0.38472069 -0.48400989  0.13366746 -0.10729363
#    0.11370732]
#  [-0.00551959  0.2139394   0.04763276  0.15545313  0.06385154  0.46243552
#   -0.21960883]
#  [-0.29225132  0.14721327 -0.09910797  0.41573303  0.07107756 -0.0837879
#    0.47389919]
#  [ 0.36437642  0.41455926  0.49751981  0.05749875 -0.30553046  0.2438197
#    0.49181523]]
# Bias: [[-0.45005545]
#  [-0.48577326]
#  [-0.16960267]
#  [-0.37679522]
#  [-0.30722656]]
# Input vector: None
# Output vector: None
#
# Properties of layer 2 :
# Number of nodes: 5
# Activation Function: <function sigmoid at 0x000001AE861C9AB0>
# Weights: [[-0.37546705  0.06914765 -0.1445907  -0.43431794  0.18265958]
#  [ 0.22759918  0.18207145 -0.44943023 -0.29231839  0.03639027]
#  [ 0.1275147  -0.48714113  0.46940944 -0.43826254 -0.16614312]]
# Bias: [[-0.37063407]
#  [-0.48878829]
#  [-0.43823763]]
# Input vector: None
# Output vector: None
#
# Properties of layer 3 :
# Number of nodes: 3
# Activation Function: <function sigmoid at 0x000001AE861C9AB0>
# Weights: [[ 0.01959056  0.1607467  -0.38436379]
#  [-0.39108654  0.39108093  0.01654258]]
# Bias: [[-0.38580708]
#  [ 0.20631642]]
# Input vector: None
# Output vector: None
#
# Properties of layer 4 :
# Number of nodes: 2
# Activation Function: None
# Weights: []
# Bias: []
# Input vector: None
# Output vector: None
# Training Network
# propogating forward
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [1167], line 26
#      23     i += 1
#      25 print("Training Network")
# ---> 26 ann.train()
#      28 i = 0
#      29 for l in ann.layers:
#
# File c:\Year 4\F20BC\F20BC-ANN\ANN.py:37, in ANN.train(self)
#      35 for j in range(self.training_epochs):
#      36     print("propogating forward")
# ---> 37     layer.Layer.propogate_forward(self.layers[0],self.layers[0].input)
#      38     for i in range(len(self.layers)-2):
#      39         print("propogating forward")
#
# File c:\Year 4\F20BC\F20BC-ANN\layer.py:22, in Layer.propogate_forward(self, input)
#      20 self.input = input
#      21 # calculate weighted sum
# ---> 22 wsum = np.dot(self.weights, input) + self.bias
#      23 # convert type to float32 [reference: https://stackoverflow.com/questions/18557337/numpy-attributeerror-float-object-has-no-attribute-exp]
#      24 wsum = np.array(wsum, dtype = np.float32)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# ValueError: shapes (7,17070) and (1,17070) not aligned: 17070 (dim 1) != 1 (dim 0)
